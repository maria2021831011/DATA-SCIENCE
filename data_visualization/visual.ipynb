# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy.random import randn , randint,uniform,sample

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('1/1/2026',periods=1000),columns=['values'])
ts=pd.Series(randn(1000),index=pd.date_range('1/1/2026',periods=1000))
df.head()
# Out:
#               values
# 2026-01-01 -0.084549
# 2026-01-02  0.059515
# 2026-01-03 -0.741968
# 2026-01-04  0.997287
# 2026-01-05  1.155189

# %%
ts
# Out:
# 2026-01-01    0.502111
# 2026-01-02    1.074456
# 2026-01-03    0.590280
# 2026-01-04   -0.905897
# 2026-01-05   -1.357136
#                 ...
# 2028-09-22   -0.308389
# 2028-09-23    1.542316
# 2028-09-24    0.905685
# 2028-09-25    0.224161
# 2028-09-26    0.242122
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot(figsize=(5,5))
# Out:
# <Axes: >

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
draw=iris.plot(figsize=(5,4),title='iris_dataset')
x=draw.set_xlabel('sepal_length')
y=draw.set_ylabel('sepal_width')
plt.show()

# %%
dd=iris.drop(columns=['species'])

# %%
dd.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
dd.iloc[0].plot(kind='bar')
# Out:
# <Axes: >

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
iris.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
dd.plot.scatter(x='sepal_length',y='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
d=dd.iloc[0]

# %%
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(7,7))
# Out:
# <Axes: ylabel='0'>

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data=tips,x='total_bill',y='tip')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='line')

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.catplot(x='day',y='total_bill',data=tips)

# %%
a=randn(100)
sns.distplot(a,bins=20 ,kde=False,color='red',rug=False,hist=True)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9404\3123107311.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a,bins=20 ,kde=False,color='red',rug=False,hist=True)
# <Axes: >

# %%
sns.pairplot(iris)
