# %%
print("ji",end="-");
print("hi");
# Out:
# ji-hi

# %%
print("hello",1,2,3,4,5,True,sep="*");
# Out:
# hello*1*2*3*4*5*True

# %%
#single line comment
print("ki")
# Out:
# ki

# %%
"""multiline comments
hig
sfkf

"""

# %%
type([1,2,3])
# Out:
# list

# %%
type((1,2,3))
# Out:
# tuple

# %%
type({1,2,3})
# Out:
# set

# %%
type({"hi":21})
# Out:
# dict

# %%
a=21
print(a)
# Out:
# 21

# %%
#input always by default string
input(

)
# Out:
# ho
# 'ho'

# %%
var=input()
# Out:
# 8

# %%
print(var)
# Out:
# 8

# %%
type(var)
# Out:
# str

# %%
var=float(var)

# %%
type(var)
# Out:
# float

# %%
a=int(input("enter a"))
b=int(input("enter b"))
res=a-b
# Out:
# enter a5
# enter b7

# %%
print(res)
# Out:
# -2
