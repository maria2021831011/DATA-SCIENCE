# %% [markdown]
# What is an Iteration
# Iteration is a general term for taking each item of something, one after another. Any time you use a loop, explicit or implicit, to go over a group of items, that is iteration

# %%
num=[1,2,3,4]
for i in num:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
#What is Iterator
#An Iterator is an object that allows the programmer to traverse through a sequence of data without having to store the entire data in the memory

import sys
num=[x for x in range(1,1000)]

print(sys.getsizeof(num))
# Out:
# 8856

# %%
num=range(1,1000)

# %%
print(sys.getsizeof(num))
# Out:
# 48

# %% [markdown]
# What is Iterable
# Iterable is an object, which one can iterate over
#
# It generates an Iterator when passed to iter() method

# %%
L = [1,2,3]
type(L)
# L is an iterable
# Out:
# list

# %%
type(iter(L))
# Out:
# list_iterator

# %%
num = [1,2,3]

# fetch the iterator
iter_num = iter(num)

# %%
print(iter_num)
# Out:
# <list_iterator object at 0x000002BF51196800>

# %%
next(iter_num)
# Out:
# 1

# %%
print(iter_num)
# Out:
# <list_iterator object at 0x000002BF51196800>

# %%
print(next(iter_num))
# Out:
# 2

# %% [markdown]
# Making our own for loop

# %%
def amr_for_loop(iterable):
    iterator = iter(iterable)
    while True:
        try:
            element = next(iterator)
            print(element)
        except StopIteration:
            break

# %%
a=[1,2,4,5,6,7]
b={"1":"one","2":"two"}
c=(10,20,30)
amr_for_loop(a)
# Out:
# 1
# 2
# 4
# 5
# 6
# 7

# %%
#generator

# %%
def my_gen():
    yield 1
    yield 2
    yield 3

# %%
gen=my_gen()
for i in gen:
    print(i)
# Out:
# 1
# 2
# 3

# %%
gen
# Out:
# <generator object my_gen at 0x000002BF518480F0>
