# %% [markdown]
# ## Common Functions/Methods
# - len
# - max
# - min
# - sorted

# %%
s="welcome maria"
len(s)
# Out:
# 13

# %%
max(s)
# Out:
# 'w'

# %%
min(s)
# Out:
# ' '

# %%
sorted(s)
# Out:
# [' ', 'a', 'a', 'c', 'e', 'e', 'i', 'l', 'm', 'm', 'o', 'r', 'w']

# %%
sorted(s,reverse=True)
# Out:
# ['w', 'r', 'o', 'm', 'm', 'l', 'i', 'e', 'e', 'c', 'a', 'a', ' ']

# %% [markdown]
# ## Strings Functions/Methods
# - Capitalize
# - Title
# - Upper
# - Lower
# - Swapcase

# %%
s.capitalize()
# Out:
# 'Welcome maria'

# %%
s.title()
# Out:
# 'Welcome Maria'

# %%
s.upper()
# Out:
# 'WELCOME MARIA'

# %%
s.lower()
# Out:
# 'welcome maria'

# %%
s.swapcase()
# Out:
# 'WELCOME MARIA'

# %%
s.cout("m")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 s.cout("m")
#
# AttributeError: 'str' object has no attribute 'cout'

# %%
s.count("m")
# Out:
# 2

# %%
s.find("l")
# Out:
# 2

# %%
s.index("l")
# Out:
# 2

# %%
print(s.endswith("a"))
# Out:
# True

# %%
print(s.startswith("e"))
# Out:
# False

# %%
name = "Bappy"
gender = "Male"

s = "My name is {}, and I am a {}"
s.format(name, gender)
# Out:
# 'My name is Bappy, and I am a Male'

# %%
name = "Bappy"
gender = "Male"

s = "My name is {1}, and I am a {0}"

# %%
s.format(name, gender)
# Out:
# 'My name is Male, and I am a Bappy'

# %% [markdown]
# f string

# %%
name="maria"
age=22
gender="female"
s={f"my name is {name}.and my age is{age}.i am {gender}"}
print(s)
# Out:
# {'my name is maria.and my age is22.i am female'}

# %% [markdown]
# - isalnum
# - isalpha
# - isdigit
# - isidentifier

# %% [markdown]
# - isalnum
# - isalpha
# - isdigit
# - isidentifier

# %%
s = "Bappy123@"

# %%
s.isalnum()
# Out:
# False

# %%
s = "123"
s.isalnum()
# Out:
# True

# %%
s = "Bappy12"

# %%
s.isalpha()
# Out:
# False

# %%
s = "12"
s.isdigit()
# Out:
# True

# %%
s = "name_age"

# %%
s.isidentifier()
# Out:
# True

# %%
s = "My name is maria"

# %%
s.split()
# Out:
# ['My', 'name', 'is', 'maria']

# %%
s = "My,name,is,maria"

# %%
s.split(",")
# Out:
# ['My', 'name', 'is', 'maria']

# %%
s = "My@name@is@maria"
p=s.split("@")

# %%
type(p)
# Out:
# list

# %%
type(s)
# Out:
# str

# %%
# join

words = ['My', 'name', 'is', 'maria']

# %%
s = " "

s = s.join(words)
print(s)
# Out:
# My name is maria

# %%
s.replace("maria","max")
# Out:
# 'My name is max'

# %%
s="    lkk"
s.strip()
# Out:
# 'lkk'

# %%
# join

words = ['My', 'name', 'is', 'Bappy']
