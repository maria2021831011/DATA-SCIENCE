# %%
#string can be define
s='str'
s="st"
s='''st'''
s="""st"""
s=str('st')
print(s)
# Out:
# st

# %%
a=33
str(a)
# Out:
# '33'

# %%
text="""i love byke." \
this isne"""
print(text)
# Out:
# i love byke." this isne

# %%
s="jsfjb dsfjdsbj"
print(s[7])
# Out:
# s

# %%
s="jsfjb dsfjdsbj"
print(s[-7])
# Out:
# s

# %%
s='sfbshv'
print(len(s))
# Out:
# 6

# %%
s='sbfcnsvnzxv'
print(s[0:3])
# Out:
# sbf

# %%
s='sbfcnsvnzxv'
print(s[0:3:2])
# Out:
# sf

# %%
s='sbfcnsvnzxv'
print(s[6:3:-1])
# Out:
# vsn

# %%
s='sbfcnsvnzxv'
print(s[9::-2])
# Out:
# xnscb

# %%
s='sbfcnsvnzxv'
print(s[::-1])
# Out:
# vxznvsncfbs

# %% [markdown]
# adding string,deleting

# %% [markdown]
# #immutable

# %%
s = "welcome to python"

# %%
s[0] = "A"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 s[0] = "A"
#
# TypeError: 'str' object does not support item assignment

# %%
del s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 del s[0]
#
# TypeError: 'str' object doesn't support item deletion

# %%
del s

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
a = "bappy"
b = "ahmed"

c = a + b

# %%
print(c)
# Out:
# bappyahmed
