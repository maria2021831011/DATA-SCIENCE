# %% [markdown]
# numpy is a python library
# it is used for working with arrays
# it is short for numerical python
# it is used for computation and processing of single and multidimensional array of elements
# smaller memory consumption and better runtime behavior

# %%
import numpy as np

# %%
l=[1,2,3,4,5]
arr=np.array(l)

# %%
print(arr)
# Out:
# [1 2 3 4 5]

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
type(l)
# Out:
# list

# %%
ar=np.array([[1,2,4],[4,5,6]])
ar
# Out:
# array([[1, 2, 4],
#        [4, 5, 6]])

# %%
ar.ndim
# Out:
# 2

# %%
arr[2]
# Out:
# np.int64(3)

# %%
dd=np.array([[[[1,2],[2,3]]]])
dd.ndim
# Out:
# 4

# %%
dd[0][0][0][1]
# Out:
# np.int64(2)

# %%
ff=np.array([1,2,3,4],dtype='float64')

# %%
print(ff)
# Out:
# [1. 2. 3. 4.]

# %%
dd.shape
# Out:
# (1, 1, 2, 2)

# %%
pp=np.array([[1,2,3,4],[3,4,5,6]])
pp[0,2]=200
print(pp)
# Out:
# [[  1   2 200   4]
#  [  3   4   5   6]]

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
type(np.zeros((2,3)))
# Out:
# numpy.ndarray

# %%
a=np.zeros((2,3))

# %%
print(a)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.dtype
# Out:
# dtype('float64')

# %%
one=np.ones((2,3),dtype='int32')

# %%
print(one)
# Out:
# [[1 1 1]
#  [1 1 1]]

# %%
b=np.full((2,3),30,dtype='float')

# %%
print(b)
# Out:
# [[30. 30. 30.]
#  [30. 30. 30.]]

# %%
np.random.rand(2,3)
# Out:
# array([[0.20996487, 0.16378146, 0.25428018],
#        [0.04679921, 0.48724003, 0.1661192 ]])

# %%
w=np.array([1,2,3,4])
h=np.array([20,30,40,40])
bmi=w/(h)**2
print(bmi)
# Out:
# [0.0025     0.00222222 0.001875   0.0025    ]

# %%
a=[1,2,3]
b=[44,5,5]
w=np.array(a)
h=np.array(b)
bmi=w/(h)**2

# %%
print(bmi)
# Out:
# [0.00051653 0.08       0.12      ]
