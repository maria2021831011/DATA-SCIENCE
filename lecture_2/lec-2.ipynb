# %%
password=input("enter pass")
email=input("enter your mail")
originpass="1234"
originemail="ddddd@gmail.com"
if email==originemail and password==originpass:
    print("success")
elif email==originemail and password!=originpass:  
    print("invalid pass")
else:
    print("no ")
# Out:
# invalid pass

# %%
#nested
password=input("enter pass")
email=input("enter your mail")
originpass="1234"
originemail="ddddd@gmail.com"
if email==originemail and password==originpass:
    print("success")
elif email==originemail and password!=originpass:  
    print("again pass")
    password=input("enter")
    if password==originpass:
        print("yes")
    else:
        print("no")    
else:
    print("no ")
# Out:
# no

# %%
#exercise 1
#identify small from 3 numbers
n1=input("enter na")
n2=input("enter na")
n3=input("enter na")
print(n1,n2,n3)
# Out:
# 2 3 4

# %%
import math
math.factorial(120)
# Out:
# 6689502913449127057588118054090372586752746333138029810295671352301633557244962989366874165271984981308157637893214090552534408589408121859898481114389650005964960521256960000000000000000000000000000

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import random
print(random.randint(3,5))
# Out:
# 3

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2025-11-03 01:52:27.865376

# %%
#modules in
# python
# !pip install fastapi
# Out:
# Access is denied.

# %%
print("OK")
# Out:
# OK

# %%
# Login Function demo - dswithbapy.com 

""" 
Actual Credentials:

Email: maria@gmail.com 
Password: ppy@12345
"""

email = input("Enter your email: ")
password = input("Enter your password: ")


actual_email = "maria@gmail.com"
actual_password = "ppy@12345"

if email == actual_email and password == actual_password:
    print("Login Successfull!")

else:
    print("Invalid Credentials!")
# Out:
# Login Successfull!

# %%
# Login Function demo - dswithbapy.com 

""" 
Actual Credentials:

Email: 73@gmail.com 
Password: ppy@12345
"""

email = input("Enter your email: ")
password = input("Enter your password: ")


actual_email = "73@gmail.com"
actual_password = "ppy@12345"

if email == actual_email and password == actual_password:
    print("Login Successfull!")

elif email == actual_email and password != actual_password:
    print("Please try again!")
    password = input("Enter your password again: ")

    if password == actual_password:
        print("Success!")
    
    else:
        print("Wrong!")


else:
    print("Invalid Credentials!")
# Out:
# Invalid Credentials!

# %% [markdown]
# if condition:
#     #write something
#
# elif condition:
#     #write something
#
#
# else:
#     #write something

# %% [markdown]
# # Modules in Python
#
# 1. Builtins Module / Package
# 2. External Module / Package
# https://docs.python.org/3/py-modindex.html
# Builtins Module / Package
# math
# keywords
# random
# datetime

# %% [markdown]
# import math

# %%
import math

# %%
math.sqrt(200)
# Out:
# 14.142135623730951

# %%
math.factorial(200)
# Out:
# 

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import datetime 

print(datetime.datetime.now())
# Out:
# 2025-11-06 07:51:46.882397

# %%
# !pip install fastapi
# Out:
# Access is denied.

# %% [markdown]
# # """
# # Exercise -1
# # Find the minimum number from 3 given number
# # """
#
# # num1 = int(input("Enter the First Number: "))
# # num2 = int(input("Enter the Second Number: "))
# # num3 = int(input("Enter the Third Number: "))
#
# # if num1<num2 and num1<num3:
# #     print("Minimum number is: ", num1)
#
# # elif num2<num1 and num2<num3:
# #     print("Minimum number is: ", num2)
#
# # else:
# #     print("Minimum number is: ", num3)
#
#
#
#
#
#
# """
# Exercise - 2
# ATM Machine menu
#
# 1. Pin change
# 2. balance check
# 3. withdraw
# 4. Deposit
# 5. Exit
# """
#
#
# menu = input("""
# Hi there! Welcome to ATM
# please choose,
#
# 1. Enter 1 for Pin change
# 2. Enter 2 for Balance check
# 3. Enter 3 for Withdraw
# 4. Enter 4 for Deposit
# 5. Enter 5 for Exit
# """)
#
#
# if menu == "1":
#     print("Pin change")
# elif menu == "2":
#     print("Balance check")
# elif menu == "3":
#     print("Withdraw")
# elif menu == "4":
#     print("Deposit")
#
# else:
#     print("Exit")
