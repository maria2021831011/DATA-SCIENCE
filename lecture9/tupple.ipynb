# %% [markdown]
# # Tuples
#
# A tuple in Python is similar to a list. The difference between the two is that we cannot change the elements of a tuple once it is assigned whereas we can change the elements of a list.
#
# In short, a tuple is an immutable list. A tuple can not be changed in any way once it is created.
#
# Characterstics
#
# - Ordered
# - Unchangeble
# - Allows duplicate
#
#
# ### Topic to be discussed
#
# - Creating a Tuple
# - Accessing items
# - Editing items
# - Adding items
# - Deleting items
# - Operations on Tuples
# - Tuple Functions

# %% [markdown]
# #tupple create

# %%
l=("maria")
print(type(l))
# Out:
# <class 'str'>

# %%
l=("maria",)
print(type(l))
# Out:
# <class 'tuple'>

# %%
#homo
a=(1,2,3,4)
#hetro
a=(1,2.3,True,[1,2,3])
#nested
a=(1,2,3,(1,2,3))
#type conversion
a=tuple('ji')

# %%
#indexing
t=(1,2,3,4)
t[2]
# Out:
# 3

# %%
t[-2]
# Out:
# 3

# %%
t[0:3]
# Out:
# (1, 2, 3)

# %%
t[::2]
# Out:
# (1, 3)

# %%
#editing item or deleting item
t[0]=3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 #editing item or deleting item
# ----> 2 t[0]=3
#
# TypeError: 'tuple' object does not support item assignment

# %%
del t[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 del t[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# type casting

# %%
t=(1,2,3,4)
print(t)
temp=list(t)
print(temp)
# Out:
# (1, 2, 3, 4)
# [1, 2, 3, 4]

# %%
temp.append(200)

# %%
print(temp)
# Out:
# [1, 2, 3, 4, 200]

# %%
L = [2,3,4]

L = tuple(L)

print(L)
# Out:
# (2, 3, 4)
