# %%
menu = {
    "Coffee": 2,
    "Pasta": 3,
    "Pizza": 5,
    "Burger": 6,
    "Chicken": 10
}

print(
    """
    Welcome to Bappy's Restaurant. Please Order Food!

    Coffee: $2
    Pasta: $3
    Pizza: $5
    Burger: $6
    Chicken: $10

    """
)
item1=input("enter your order item:")
total_price=0
if item1 in menu:
    total_price+=menu[item1]
    print(f"you order item ${item1}.which price ${total_price}")
else:
    print("invalid order")

another_order = input("Do you want to add another item? (Yes/No): ").lower()

if another_order == "yes":
    item2 = input("Enter the name of the 2nd item you want to order: ")
    if item2 in menu:
        total_price += menu[item2]
        print(f"You ordered {item2}. Your total order is ${total_price}")
    
    else:
        print("Invalid item, Please order something from the Menu")

    

print(f"Your total ammount is ${total_price}. Thank you!")
# Out:
#     Welcome to Bappy's Restaurant. Please Order Food!
#
#     Coffee: $2
#     Pasta: $3
#     Pizza: $5
#     Burger: $6
#     Chicken: $10
#
#
# you order item $Coffee.which price $2
# You ordered Pizza. Your total order is $7
# Your total ammount is $7. Thank you!
