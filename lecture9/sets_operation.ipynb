# %%
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}

# %%
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1 & s2
# Out:
# {4, 5}

# %%
s1 - s2
# Out:
# {1, 2, 3}

# %%
s2 - s1
# Out:
# {6, 7, 8}

# %%
s2 ^ s1
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
s1 = {1,2,3,4,5}

1 not in s1
# Out:
# False

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
for i in s1:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
