# %%
def movement():
    print("I can move")
def fire_detection_01():
    print("Fire detected!")
def wheel_malfunction():
    print("wheel malfunctioning")
movement()  

def movement():
    print("I can move")
def fire_detection_01():
    print("Fire detected!")
def wheel_malfunction():
    print("wheel malfunctioning")
movement()
# Out:
# I can move
# I can move

# %%
#using oop

# %%
class Robot:
    def __init__(self, robot_number):
        self.robot_number = robot_number

    def movement(self):
        print("I can move")

    def fire_detection(self):
        print("Fire detected!")

    def wheel_malfunction(self):
        print("Wheel malfunctioning")


# Object creation
res1 = Robot(robot_number=1)
res1.movement()
# Out:
# I can move

# %%
#class vs object
L = [1,2,3,4]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 #class vs object
#       2 L = [1,2,3,4]
# ----> 3 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
S = "Bappy"
S.append("F")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 S = "Bappy"
# ----> 2 S.append("F")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
a = 66
a[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 a = 66
# ----> 2 a[0] = 1
#
# TypeError: 'int' object does not support item assignment

# %%
i = int()

# %%
S = "inception"
print(type(S))
# Out:
# <class 'str'>

# %%
samsung = mobile()
iphone = mobile()
Vivo = mobile()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 samsung = mobile()
#       2 iphone = mobile()
#       3 Vivo = mobile()
#
# NameError: name 'mobile' is not defined
