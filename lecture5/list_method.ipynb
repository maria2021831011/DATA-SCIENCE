# %% [markdown]
# ## Lists Methods/Functions
# list are mutable

# %% [markdown]
# l=[1,2,3,4,5]
# print(l)

# %%
l=[1,2,3,4]
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l.append(7)
print(l)
# Out:
# [1, 2, 3, 4, 7, 7]

# %%
l[0]=100
print(l)
# Out:
# [100, 2, 3, 4, 7, 7]

# %%
#but string doesnt
s="maria"
s[0]="q"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 #but string doesnt
#       2 s="maria"
# ----> 3 s[0]="q"
#
# TypeError: 'str' object does not support item assignment

# %%
#slicing
l[1:4]=[100,200,300]
print(l)
# Out:
# [100, 100, 200, 300, 7, 7]

# %%
l.append([1,2,3],True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 l.append([1,2,3],True)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l.append([1,2,3])
print(l)
# Out:
# [100, 100, 200, 300, 7, 7, [1, 2, 3]]

# %%
L = [1,2,3,4]

a = [10,11,12]

L.extend(a)

print(L)
# Out:
# [1, 2, 3, 4, 10, 11, 12]

# %%
L.extend("hi")
print(L)
# Out:
# [1, 2, 3, 4, 10, 11, 12, 'h', 'i']

# %%
#insert
L.insert(1,400)
print(L)
# Out:
# [1, 400, 2, 3, 4, 10, 11, 12, 'h', 'i']

# %%
del L[0]
print(L)
# Out:
# [400, 2, 3, 4, 10, 11, 12, 'h', 'i']

# %%
del L[1:3]

print(L)
# Out:
# [400, 4, 10, 11, 12, 'h', 'i']

# %%
L = [1,2,3,4]

L.remove(4)

print(L)
# Out:
# [1, 2, 3]

# %%
L = [1,2,3,4]

L.pop()
L.pop()
print(L)
# Out:
# [1, 2]

# %%
L = [1,2,3,4]

L.clear()

print(L)
# Out:
# []

# %%
#min/max/sorted
l=[1,2,3,4,5,6,3,2,3]
print(len(l))
print(min(l))
print(max(l))
print(sorted(l))
print(sorted(l,reverse=True))
# Out:
# 9
# 1
# 6
# [1, 2, 2, 3, 3, 3, 4, 5, 6]
# [6, 5, 4, 3, 3, 3, 2, 2, 1]

# %%
#INDEX,COUNT
print(l.count(3))
# Out:
# 3

# %%
print(l.index(2))
# Out:
# 1

# %%
print(l.reverse())
# Out:
# None

# %%
L = [1,2,3,4]

L.reverse()
print(L)
# Out:
# [4, 3, 2, 1]

# %%
L = [4,2,1,55,10]
L.sort()
print(L)
# Out:
# [1, 2, 4, 10, 55]

# %%
L = [1,2,3,4]

l1 = L.copy()

print(l1)
# Out:
# [1, 2, 3, 4]

# %%
l1.append(99)

# %%
print(l1)
print(L)
# Out:
# [1, 2, 3, 4, 99]
# [1, 2, 3, 4]

# %%
id(L)
# Out:
# 2991880192832

# %%
id(l1)
# Out:
# 2991880195840
