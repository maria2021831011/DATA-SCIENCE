# %%
def pp(name):
    abss=(f"hei {name}")
    print(abss)
pp("maria")
# Out:
# hei maria

# %%
def pp():
    abss=(f"hei ")
    print(abss)
pp()
# Out:
# hei

# %%
def pp(name):
    abss=(f"hei {name}")
    return abss
ab=pp("maria")  
print(ab)
# Out:
# hei maria

# %%
def res(name):
    abss=(f"my name is {name}")
    print(abss)
l=["maria","jakia","takia"]
for i in l :
    res(i)
# Out:
# my name is maria
# my name is jakia
# my name is takia

# %%
def even(num):
    if num%2==0:
        return "even number"
    else:
        return "odd number"
store=even(4)
print(store)
# Out:
# even number

# %%
for i in range(1,11):
     st=even(i)
     print(st)
# Out:
# odd number
# even number
# odd number
# even number
# odd number
# even number
# odd number
# even number
# odd number
# even number

# %%
#docstrings in function
def even(num):
    """this function check even or odd number
    input:integer
    output:even/odd
    created date:10-10-2025"""
    if num%2==0:
        return "even number"
    else:
        return "odd number"
store=even(4)
print(store)
# Out:
# even number

# %%
print(even.__doc__)
# Out:
# this function check even or odd number
# input:integer
# output:even/odd
# created date:10-10-2025

# %%
print(max.__doc__)
# Out:
# max(iterable, *[, default=obj, key=func]) -> value
# max(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its biggest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more positional arguments, return the largest argument.

# %%
print(len.__doc__)
# Out:
# Return the number of items in a container.

# %% [markdown]
# parameter vs argument

# %% [markdown]
# #docstrings in function
# def even(num):
#     """this function check even or odd number
#     input:integer
#     output:even/odd
#     created date:10-10-2025"""
#     if num%2==0:
#         return "even number"
#     else:
#         return "odd number"
# store=even(4)
# print(store)

# %%
#docstrings in function
def even(num): #num is parameter 
    """this function check even or odd number
    input:integer
    output:even/odd
    created date:10-10-2025"""
    if num%2==0:
        return "even number"
    else:
        return "odd number"
store=even(4) # now arguments when we pass vlaue
print(store)

# %% [markdown]
# type of argument
# 1.deafult
# 2.positional
# 3.keyword

# %%
# default argument
def val(a=3,b=2):
    return a**b
pas=val()
print(pas)
# Out:
# 9

# %%
#positiponal
def val(a=3,b=2):
    return a**b
pas=val(3,8)
print(pas)
# Out:
# 6561

# %%
#keyvalue
def val(a=3,b=2):
    return a**b
pas=val(b=3,a=2)
print(pas)
# Out:
# 8

# %% [markdown]
# ### `*args and **kwargs`
# `*args and **kwargs` are special Python keywords that are used to pass the variable length of arguments to a function
#
# # *args
# # allows us to pass a variable number of non-keyword arguments to a function.

# %%
def multiply(a,b,c,d):
    return a*b*c*d

# %%
res=multiply(2,3,7,5)
print(res)
# Out:
# 210

# %%
def mul(*mar):
    p=1
    for i in mar:
        p=p*i
    return p

# %%
res=mul(1,2,3,3,4,5,6,5,6,7,45,3,4,5,6,7)
print(res)
# Out:
# 51438240000

# %% [markdown]
# # **kwargs
# # **kwargs allows us to pass any number of keyword arguments.
# # Keyword arguments mean that they contain a key-value pair, like a Python dictionary.

# %%
def dis(**mar):
    for key,val in mar.items():
        print(f"{key}->{val}")

# %%
dis(dhaka="bd",india="delhi")
# Out:
# dhaka->bd
# india->delhi

# %% [markdown]
# how function ARE EXEcute in memory

# %%
def odd(num):
    if num%2==0:
        return "even"
    else:
        return "odd"

# %%
print(odd(5))
# Out:
# odd

# %% [markdown]
# function without return statement

# %%
def odd(num):
    if num%2==0:
        print("even")
    else:
        print("odd")  
print(odd(7))
# Out:
# odd
# None

# %% [markdown]
# # Variable Scope in Functions
#  - Global Variables
#  - Local Variables

# %%
def g(y):
    print(x)
    print(x+1)

x=5 #global
g(x)
print(x)
# Out:
# 5
# 6
# 5

# %%
def g(y):
    x=1#local
    print(x)
    print(x+1)

x=5 #global
g(x)
print(x)
# Out:
# 1
# 2
# 5

# %%
def g(y):
    z=1

    print(x)
    print(x+1)

x=5 #global
g(x)
print(x)  
print(z)
# Out:
# 5
# 6
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 10
#       8 g(x)
#       9 print(x)
# ---> 10 print(z)
#
# NameError: name 'z' is not defined

# %% [markdown]
# nested function

# %%
def f():
    def g():
        print("nested inside g")

    g()
    print("nested inside f")

# %%
f()
# Out:
# nested inside g
# nested inside f

# %%
g()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 g()
#
# TypeError: g() missing 1 required positional argument: 'y'

# %%
def f():
    def g():
        print("nested inside g")
        f()

    g()
    print("nested inside f")

# %%
f()
# Out:
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# nested inside g
# ...

# %% [markdown]
# Functions are 1st class citizens
# It acts like data types
#
# https://en.wikipedia.org/wiki/First-class_citizen

# %%
def square(num):
    return num**2
print(type(square))
print(id(square))
# Out:
# <class 'function'>
# 2526197335520

# %%
#reassign
x=square
id(x)
# Out:
# 2526197335520

# %%
x(7)
# Out:
# 49

# %%
del square
print(square)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 del square
# ----> 2 print(square)
#
# NameError: name 'square' is not defined

# %%
def n(num):
     return num**2
l=[1,2,3,4,n]
l[-1](8)
# Out:
# 64

# %%
s={n}
s
# Out:
# {<function __main__.n(num)>}

# %%
def f():
    def g(a,b):
        return a+b
    return g
print(f()(3,4))
# Out:
# 7

# %% [markdown]
# # Benefits of using a Function
#
# - Code Modularity
# - Code Readibility
# - Code Reusability
#
# ### Lambda Function
#
# A lambda function is a small anonymous function.
#
# A lambda function can take any number of arguments, but can only have one expression.

# %%
x=lambda z:z**2
x(5)
# Out:
# 25

# %%
x=lambda a,b:a+b
x(2,3)
# Out:
# 5

# %%
x=lambda a:'even'if a%2==0 else 'odd'
x(7)
# Out:
# 'odd'

# %% [markdown]
# ### Diff between lambda vs Normal Function
#
# - No name
# - lambda has no return value(infact,returns a function)
# - lambda is written in 1 line
# - not reusable
#
# Then why use lambda functions?<br>
# **They are used with HOF**

# %% [markdown]
# higher order function

# %%
l=[1,2,3,4,5]
def sq(num):
    return num**2
def cube(num):
    return num**3
def trans(f,l):
    output=[]
    for i in l:
        output.append(f(i))


    print(output)
trans(cube,l)
# Out:
# [1, 8, 27, 64, 125]

# %%
trans(lambda x:x**4,l)
# Out:
# [1, 16, 81, 256, 625]

# %% [markdown]
# # Higher Order Functions
# - map
# - filter
# - reduce

# %%
#map
l=[1,2,4,5]
list(map(lamda x:x**2,l))
# Out:
#   Cell In[39], line 3
#     list(map(lamda x:x**2,l))
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# square the items of a list
L = [1,2,3,4,5]

list(map(lambda x: x**2, L))
# Out:
# [1, 4, 9, 16, 25]

# %%
user=[{
    'name':'maria',
    'age':20,
    'gender':'female'
},
{
    'name':'aiza',
    'age':22,
    'gender':'male'
}

]
list(map(lambda user:user['name'],user))
# Out:
# ['maria', 'aiza']

# %%
#filter
fruit=['banana','apple']
list(filter(lambda x:x.startswith('a'),fruit))
# Out:
# ['apple']

# %%
#reduce
import functools
l=[1,2,3,4,5]
functools.reduce(lambda x,y:x+y,l)
# Out:
# 15

# %% [markdown]
# Enumerate Function in Python

# %%
name=['ami','tmi','she']
for i ,na in enumerate(name,start=1):
    print(i,na)
# Out:
# 1 ami
# 2 tmi
# 3 she

# %%
name=['ami','tmi','she']
for i ,na in enumerate(name,start=1):
    if i==3:
       print(i,na)
# Out:
# 3 she

# %% [markdown]
# Assignment 4: Bus Ticket Discount Problem:
#
# Ask the user for age and print ticket price:
#
# ● Below 5 → Free
#
# ● 5–18 → 50% Discount
#
# ● 60 or above → 30% Discount
#
# ● Others → Full Price

# %%
age = int(input("Enter your age: "))

if age < 5:
    print("Free")

elif age <= 18:
    print("50% Disscount")


elif age >= 60:
    print("30% Discount")


else:
    print("Full Price")
